# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\glass.csv")
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
sns.pairplot(data=df, hue='Type')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, annot_kws={'size': 10})
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('Type', axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('Type', axis=1))
scaled_features
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]], shape=(214, 9))

# %%
Glass_df = pd.DataFrame(scaled_features, columns=df.columns[:-1])
Glass_df.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1 -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2 -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3 -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4 -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
#
#          Ba        Fe
# 0 -0.352877 -0.586451
# 1 -0.352877 -0.586451
# 2 -0.352877 -0.586451
# 3 -0.352877 -0.586451
# 4 -0.352877 -0.586451

# %%
from sklearn.model_selection import train_test_split
X = Glass_df
y = df['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=48)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (149, 9)
# (65, 9)
# (149,)
# (65,)

# %% [markdown]
# **Support Vector Machine**

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
svm = SVC()
svm.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred_svm = knn.predict(X_test)
y_pred_svm
# Out:
# array([1, 1, 1, 7, 2, 2, 1, 1, 1, 1, 2, 3, 7, 2, 1, 7, 2, 2, 1, 1, 2, 1,
#        2, 2, 1, 2, 1, 2, 2, 2, 5, 7, 7, 2, 7, 5, 2, 1, 1, 7, 5, 1, 1, 2,
#        1, 2, 7, 1, 1, 6, 2, 1, 5, 1, 7, 1, 2, 6, 2, 1, 2, 1, 2, 1, 1])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_pred_svm))
print("\n CONFUSION MATRIX:")
print(confusion_matrix(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      1.00      0.71        15
#            2       0.82      0.69      0.75        26
#            3       1.00      0.14      0.25         7
#            5       0.25      0.33      0.29         3
#            6       1.00      0.67      0.80         3
#            7       1.00      0.82      0.90        11
#
#     accuracy                           0.71        65
#    macro avg       0.77      0.61      0.62        65
# weighted avg       0.79      0.71      0.69        65
#
#
#  CONFUSION MATRIX:
# [[15  0  0  0  0  0]
#  [ 5 18  0  3  0  0]
#  [ 4  2  1  0  0  0]
#  [ 1  1  0  1  0  0]
#  [ 0  1  0  0  2  0]
#  [ 2  0  0  0  0  9]]

# %% [markdown]
# **K Nearest Neighbours**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred_knn = knn.predict(X_test)
y_pred_knn
# Out:
# array([1, 1, 1, 6, 2, 1, 1, 1, 1, 1, 1, 3, 7, 2, 1, 7, 2, 2, 1, 1, 2, 1,
#        2, 2, 1, 1, 1, 2, 2, 2, 5, 7, 7, 2, 7, 2, 2, 1, 1, 7, 5, 1, 1, 2,
#        1, 2, 7, 1, 1, 5, 2, 1, 5, 1, 7, 1, 2, 6, 2, 1, 2, 1, 2, 1, 1])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_pred_knn))
print("\n CONFUSION MATRIX:")
print(confusion_matrix(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67        15
#            2       0.90      0.69      0.78        26
#            3       1.00      0.14      0.25         7
#            5       0.25      0.33      0.29         3
#            6       0.50      0.33      0.40         3
#            7       1.00      0.73      0.84        11
#
#     accuracy                           0.68        65
#    macro avg       0.69      0.54      0.54        65
# weighted avg       0.79      0.68      0.67        65
#
#
#  CONFUSION MATRIX:
# [[15  0  0  0  0  0]
#  [ 6 18  0  2  0  0]
#  [ 5  1  1  0  0  0]
#  [ 2  0  0  1  0  0]
#  [ 0  1  0  1  1  0]
#  [ 2  0  0  0  1  8]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.676923076923077

# %%
# The question now is to find the value of K that gives better accuracy
# this can be done using elbow method
err_rate = []
for m in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=m)
    knn.fit(X_train,y_train)
    ypred_m = knn.predict(X_test)
    err_rate.append(np.mean(ypred_m!=y_test))

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1,30), err_rate)
plt.xlabel('K Value')
plt.ylabel('Error Rate')
plt.title('Error Rate Vs K Value Plot')
# Out:
# Text(0.5, 1.0, 'Error Rate Vs K Value Plot')

# %%
# now use K=4 and find accuracy score
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
accuracy_score(y_test,y_pred_knn)
# higher accuracy score indicates that for K value of 4 model performs better
# elbow method to find optimum value of K gives better model performance
# Out:
# 0.676923076923077

# %%
df = pd.DataFrame({
    "SVM Prediction": y_pred_svm,
    "KNN Prediction": y_pred_knn
})

print(df.head())
# Out:
#    SVM Prediction  KNN Prediction
# 0               1               1
# 1               1               1
# 2               1               1
# 3               7               6
# 4               2               2

# %%
comparison_df = pd.DataFrame({
    "Actual": y_test,      
    "SVM": y_pred_svm,
    "KNN": y_pred_knn
})

print(comparison_df.head())
# Out:
#      Actual  SVM  KNN
# 41        1    1    1
# 26        1    1    1
# 31        1    1    1
# 190       7    7    6
# 95        2    2    2

# %%
comparison_df["Same Prediction"] = comparison_df["SVM"] == comparison_df["KNN"]
comparison_df.head()
# Out:
#      Actual  SVM  KNN  Same Prediction
# 41        1    1    1             True
# 26        1    1    1             True
# 31        1    1    1             True
# 190       7    7    6            False
# 95        2    2    2             True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data for heatmap
# Transpose so that models are rows and samples are columns
heatmap_data = comparison_df[["Actual", "SVM", "KNN"]].T

plt.figure(figsize=(15, 4))

# Create heatmap
sns.heatmap(
    heatmap_data,
    cmap="coolwarm",          # red-blue colormap for contrast
    cbar=False,               # hide color bar (optional)
    linewidths=0.5,           # thin lines between cells
    linecolor="gray",         # line color
    annot=True,               # show values inside cells
    fmt="d",                  # integer format
    xticklabels=heatmap_data.columns,  # sample indices
    yticklabels=heatmap_data.index     # Actual, SVM, KNN
)

# Labels and title
plt.xlabel("Test Sample", fontsize=12)
plt.ylabel("Model", fontsize=12)
plt.title("Heatmap: Actual vs SVM vs KNN Predictions", fontsize=14, fontweight="bold")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

# Scatter plots for clarity
plt.scatter(comparison_df.index, comparison_df["Actual"], 
            marker='o', color='black', label="Actual", s=80)

plt.scatter(comparison_df.index, comparison_df["SVM"], 
            marker='x', color='blue', label="SVM", s=80)

plt.scatter(comparison_df.index, comparison_df["KNN"], 
            marker='s', color='green', label="KNN", s=80)

# Labels and title
plt.xlabel("Test Sample", fontsize=12)
plt.ylabel("Class", fontsize=12)
plt.title("Actual vs SVM vs KNN Predictions", fontsize=14, fontweight='bold')

# Y-axis ticks for categorical classes
plt.yticks([0, 1], ["Benign (0)", "Malignant (1)"])

# Legend and grid
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
