# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\houseprice.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
sns.displot(df['total_bedrooms'])

# %%
numerical_col = df.select_dtypes(include = ['int', 'float'])

# %%
numerical_col
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(numerical_col.corr(), annot=True)
plt.show()

# %%
df['total_rooms'].describe()
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
def findOutliers(d,col):
    column = col 
    x = d[column].describe()
    print(x)
    y = {"count":0,"mean":1,"std":2,"min":3,"25":4,"50":5,"75":6,"max":7}
    Q25 = x[y['25']]
    Q75 = x[y['75']]
    IQR = Q75-Q25
    lowerBound = Q25-1.5*IQR
    upperBound = Q75+1.5*IQR
    data = d[(d[column] < lowerBound) | (d[column] > upperBound)]
    print(f"No. of outliers: {len(data[column])}, out of {len(d[column])}")
    #let's remove outliers from the data frame and store in z variable
    z = df[~d[column].isin(data[column])]
    return z

# %%
df_cleaned = findOutliers(df,"total_rooms")
df = df_cleaned
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64
# No. of outliers: 1287, out of 20640
# C:\Windows\Temp\ipykernel_9760\2195748191.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Q25 = x[y['25']]
# C:\Windows\Temp\ipykernel_9760\2195748191.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Q75 = x[y['75']]

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        196
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan,strategy ="median")
imputer.fit(df.iloc[:,4:5])
df.iloc[:,4:5] = imputer.transform(df.iloc[:,4:5])
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# now manipulate the ocean_proximity field and change it using label encoder
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
print(df["ocean_proximity"].value_counts())
df["ocean_proximity"] = labelEncoder.fit_transform(df["ocean_proximity"])
df["ocean_proximity"].value_counts()
df.describe()
# Out:
# ocean_proximity
# <1H OCEAN     8590
# INLAND        6048
# NEAR OCEAN    2530
# NEAR BAY      2180
# ISLAND           5
# Name: count, dtype: int64
# C:\Windows\Temp\ipykernel_9760\1052353577.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ocean_proximity"] = labelEncoder.fit_transform(df["ocean_proximity"])
#           longitude      latitude  housing_median_age   total_rooms  \
# count  19353.000000  19353.000000        19353.000000  19353.000000
# mean    -119.591048     35.647446           29.522193   2225.118793
# std        2.000904      2.142796           12.308489   1153.906566
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.810000     33.940000           19.000000   1406.000000
# ...

# %%
df.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3139     -118.17     34.87                   9         1507           293.0
# 9873     -121.83     36.61                  27         2248           466.0
# 12922    -121.32     38.66                  21         1276           208.0
# 1186     -121.55     39.45                  18         2278           523.0
# 7675     -118.09     33.92                  36          847           185.0
# 13444    -117.43     34.08                  13         4563          1187.0
# 10396    -117.67     33.55                   6         3157           721.0
# 7115     -118.01     33.91                  32         2722           571.0
# 13320    -117.67     34.06                  26         1592           429.0
# 11054    -117.86     33.78                  25         2635           660.0
#
#        population  households  median_income  median_house_value  \
# 3139          761         278         3.0184               87900
# ...

# %%
df.loc[3, 'latitude']
# Out:
# np.float64(37.85)

# %%
df.iloc[0, 1]
# Out:
# np.float64(37.88)

# %%
from sklearn.model_selection import train_test_split
X =  df.drop('median_house_value', axis=1)
y = df['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=5)

# %%
X_train.shape
# Out:
# (15482, 9)

# %%
y_train.shape
# Out:
# (15482,)

# %%
y_test.shape
# Out:
# (3871,)

# %%
X_test.shape
# Out:
# (3871, 9)

# %%
X_test.size
# Out:
# 34839

# %%
# use scaler to make sure that no independent variable dominates the model
from sklearn.preprocessing import StandardScaler
independent_scaler = StandardScaler()
X_train = independent_scaler.fit_transform(X_train)
X_test = independent_scaler.transform(X_test)

# %%
# use linear regression
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 205005.05722774824

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([141252.73896366, 255814.79696388, 291181.84890049, ...,
#        558821.19550752, 159701.46560157, 273946.77435531], shape=(3871,))

# %%
print(f"Model's predictions: {predictions[0:5]}")
print('\n\n')
print(f'actual output: \n {y_test[0:5]}')
# Out:
# Model's predictions: [141252.73896366 255814.79696388 291181.84890049 126543.58263898
#  307449.91679397]
#
#
#
# actual output:
#  4975     124000
# 7761     167600
# 8746     446800
# 12863     88200
# 17610    320500
# Name: median_house_value, dtype: int64

# %%
plt.scatter(y_test,predictions)

# %%
results = pd.DataFrame( {'Predictions' : predictions, 'Actual': y_test})

# %%
sns.heatmap(results.corr(), annot =True)
# Out:
# <Axes: >

# %%
sns.histplot((y_test-predictions),bins=50)
plt.show()

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 50842.84233004172
# MSE: 4747266179.277188
# RMSE: 68900.40768585617

# %%
results = pd.DataFrame({'Predicted':predictions,'Actual':y_test})
results = results.reset_index()
results = results.drop(['index'],axis=1)
fig= plt.figure(figsize=(16,8))
plt.plot(results[:50])
plt.legend(['Actual','Prediction'])
plt.show()

# %%
sns.jointplot(x='Actual',y='Predicted',data=results,kind='reg',)
plt.show()

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
test_input = {
    "longitude": -118.25,   
    "latitude": 34.05,            
    "housing_median_age": 28,     
    "total_rooms": 3500,      
    "total_bedrooms": 700,        
    "population": 1500,           
    "households": 500,            
    "median_income": 4.5,   
    "ocean_proximity": 2
}

# %%
test_input = pd.DataFrame([test_input])

# %%
test_input = independent_scaler.transform(test_input)

# %%
test_output = lm.predict(test_input)
print(f"{test_output}")
# Out:
# [254421.28578251]

# %%
import joblib

# Suppose your trained model is called 'model'
# Save it to a file
joblib.dump(lm, "house_price_Prediction_model.pkl")

# Later, load it back into a variable
loaded_model = joblib.load("house_price_Prediction_model.pkl")

# Now you can use loaded_model just like the original
prediction = loaded_model.predict(X_test)
